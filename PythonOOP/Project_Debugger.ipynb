# %%
# __author__ = John Boudreaux
class strategy:
    '''An object to contain different types of strategies for the El Farol
    problem that can be adopted by different agents. Expects a "strat_type" arg,
    which descibes the type of strategy adopted. Valid strategy options include:
    "same_as_past", which picks a strategy from n iterations ago,
    "flip", which takes the number of attendees at week n and subtracts it
    from the total number of agents,
    "minimum_of_last", which will return the minimum attendees from
    the last n iterations,
    "avg", which takes the average of the past n weeks,
    "maximum_of_last", which will return the maximum attendees from the last
    n iterations'''

    approved_strats = ["same_as_past", "flip", "minimum_of_last", "avg", "maximum_of_last"]

    def __init__(self, strat_type, n):
        if strat_type not in strategy.approved_strats:
            raise ValueError("Please pick an approved strategy from documentation")
        else:
            self.strat_type =  strat_type
            self.n = n

    def strat_evaluate(self, num_of_agents, history, n, strat_type):
        '''A script to evaluate the strategy for a given agent and the history'''
        # note to self: I wish Python had a convenient switch/case protocol
        # all scripts here follow similar order: what to do if the length of the
        # history is zero, then if it is less than the required n, and then the
        # general case.

        if strat_type == "same_as_past":
            if len(history) < n:
                if len(history) == 0:
                    expected_num = 0
                else:
                    expected_num = history[0]
            else:
                expected_num = history[len(history)-n]

        elif strat_type == "flip":
            if len(history) < n:
                expected_num = num_of_agents
            else:
                expected_num = num_of_agents - history[len(history)-n]

        elif strat_type == "minimum_of_last":
            if len(history) < n:
                if len(history) == 0:
                    expected_num = 0
                else:
                    valid_search = history[0:len(history)]
                    expected_num = min(valid_search)
            else:
                valid_search = history[(len(history)-n):len(history)]
                expected_num = min(valid_search)

        elif strat_type == "maximum_of_last":
            if len(history) < n:
                if len(history) == 0:
                    expected_num = num_of_agents
                else:
                    valid_search = history[0:len(history)]
                    expected_num = max(valid_search)
            else:
                valid_search = history[(len(history)-n):len(history)]
                expected_num = max(valid_search)

        elif strat_type == "avg":
            if len(history) < n:
                if len(history) == 0:
                    expected_num = round(num_of_agents / 2)
                else:
                    valid_search = history[0:len(history)]
                    expected_num = round(sum(valid_search)/len(valid_search))
            else:
                valid_search = history[(len(history)-n):len(history)]
                expected_num = round(sum(valid_search)/len(valid_search))

        return(expected_num)

# %%
# __author__ = John Boudreaux

class agent:
    '''A class to store properties about agents for El Farol and minority
    problem games. Expects a memory length as an integer (default is 2),
    and a number of strategies as an integer'''

    def __init__(self, memory_length=3, num_strats=3):
        # need to select n at random from uniform distribution,
        # strategy at random from uniform distribution
        available_strats = strategy.approved_strats
        self.current_strat = {"index": None, "expected_val": None, "go": None}
        # python 3.6 has a more convenient random.choices() operation,
        # but I am only assuming verion >= 3.5
        self.strategies = {}
        for i in range(0, num_strats):
            picked_strat = random.choice(available_strats)
            picked_n = random.choice(range(1, memory_length+1))
            self.strategies[i] = {'strat': strategy(picked_strat, picked_n),\
                                  'n': picked_n, 'votes': 0,
                                 'strat_type': picked_strat}

    def select_and_eval_strat(self, history, cutoff_val):
        # although it may seem a bit much to have both selection and evaluation
        # in one method, it will reduce the number of temporary objects
        votes_list = [self.strategies[i]['votes'] for i in range(len(self.strategies))]
        max_votes = max(votes_list)
        max_indices = [index for index, val in enumerate(votes_list) if val == max_votes]
        # choose the strategy with the most votes. if tied, choose random
        if len(max_indices) > 1:
            which_index = random.choice(max_indices)
        else:
            which_index = max_indices[0]
        active_strat = self.strategies[which_index]
        self.current_strat['index'] = which_index
        # evaluate the selected strategy, bring back the expected val
        # provide convenient vars for readability
        local_n = self.strategies[which_index]['n']
        local_strat_type = self.strategies[which_index]['strat'].strat_type
        num_of_agents = sim.num_of_agents
        expected_val = active_strat['strat'].strat_evaluate(num_of_agents, \
                       history, n = local_n, strat_type = local_strat_type)
        self.current_strat['expected_val'] = expected_val

        if expected_val < cutoff_val:
            self.current_strat['go'] = 1
        else:
            self.current_strat['go'] = 0

    def update_votes(self, winning_num):
        #function to update the votes for strategies
        which_index = self.current_strat['index']

        if self.current_strat['go'] == winning_num:
            self.strategies[which_index]['votes'] += 1
        else:
            self.strategies[which_index]['votes'] -= 1

# %%
# __author__ = John Boudreaux

class simulation:
    '''A class to house all the parameters for a simulation of the El Farol
    problem, and to store its outputs'''
    # going to need to pass all parameters through here, since agents are More
    # or less a child class, and strategies are a child class of agents

    def __init__(self, num_of_agents, iterations, cutoff_val, mem_length, num_strats):
        '''Simulation object expects agents of class agent,
         and a number of iterations that is an integer'''
        self.num_of_agents = num_of_agents
        self.mem_length = mem_length
        self.target_value = math.ceil(cutoff_val * self.num_of_agents)
        self.iterations = iterations
        self.num_strats = num_strats
        self.history = []
        # create an object to contain all the agents and create them
        self.agents = {}
        for i in range(self.num_of_agents):
            self.agents[i] = agent(memory_length = self.mem_length, num_strats = self.num_strats)


    def run_simulation(self):
        '''Code to loop through and run simulation. Takes variables from
        namespace of simulation'''
        print("Beginning simulation")
        for i in range(self.iterations):
            agents_going_to_bar = 0
            for j in range(len(self.agents)):
                self.agents[j].select_and_eval_strat(history = self.history, cutoff_val = self.target_value)
                agents_going_to_bar += self.agents[j].current_strat['go']

            # if the total amount of agents at the bar is above the target value,
            # I would have had more fun staying home
            self.history.append(agents_going_to_bar)

            if agents_going_to_bar > self.target_value:
                winning_val = 0
            else:
                winning_val = 1

            for j in range(len(self.agents)):
                self.agents[j].update_votes(winning_val)

            if i % 10 == 0:
                print("Iteration", i, "of", self.iterations, "completed!")

        print("Simulation completed!")

        # loop for number of simulations
            # select the strategy and evaluate it as a go/no go
            # record total number of gos, append history. figure out whether go or no go was a win
            # if the strategy is successful, add a vote to it. if not, take away a vote
        #

# %%
import random
import math
# fun text from: https://www.messletters.com/en/big-text/
print(""":::::::::: :::         ::::::::::     :::     :::::::::   ::::::::  :::
:+:        :+:         :+:          :+: :+:   :+:    :+: :+:    :+: :+:
+:+        +:+         +:+         +:+   +:+  +:+    +:+ +:+    +:+ +:+
+#++:++#   +#+         :#::+::#   +#++:++#++: +#++:++#:  +#+    +:+ +#+
+#+        +#+         +#+        +#+     +#+ +#+    +#+ +#+    +#+ +#+
#+#        #+#         #+#        #+#     #+# #+#    #+# #+#    #+# #+#
########## ##########  ###        ###     ### ###    ###  ########  ##########  """)
print("")
print("Let's run a simulation of the El Farol problem. I'll need a few parameters...")
print("")
# Out:
# :::::::::: :::         ::::::::::     :::     :::::::::   ::::::::  :::
# :+:        :+:         :+:          :+: :+:   :+:    :+: :+:    :+: :+:
# +:+        +:+         +:+         +:+   +:+  +:+    +:+ +:+    +:+ +:+
# +#++:++#   +#+         :#::+::#   +#++:++#++: +#++:++#:  +#+    +:+ +#+
# +#+        +#+         +#+        +#+     +#+ +#+    +#+ +#+    +#+ +#+
# #+#        #+#         #+#        #+#     #+# #+#    #+# #+#    #+# #+#
# ########## ##########  ###        ###     ### ###    ###  ########  ##########
#
# Let's run a simulation of the El Farol problem. I'll need a few parameters...

# %%
# user input for parameter selection
iterations = int(input("Select a number of iterations for your simulation: "))
num_of_agents = int(input("Select a number of agents for your simulation: "))
mem_length = int(input("Select a number for the length of the agent memories: "))
num_strats = int(input("Select a number of strategies for each agent: "))
cutoff = int(input("Select a cutoff percentage (integer value): ")) / 100
seed = int(input("Choose a seed value (integer value): "))

print("")
# Out:
# Select a number of iterations for your simulation: 10000
# Select a number of agents for your simulation: 500
# Select a number for the length of the agent memories: 10
# Select a number of strategies for each agent: 3
# Select a cutoff percentage (integer value): 60
# Choose a seed value (integer value): 45

# %%
sim = simulation(num_of_agents, iterations, cutoff, mem_length, num_strats)
sim.run_simulation()

print(sim.history)
# Out:
# Beginning simulation
# Iteration 0 of 10000 completed!
# Iteration 10 of 10000 completed!
# Iteration 20 of 10000 completed!
# Iteration 30 of 10000 completed!
# Iteration 40 of 10000 completed!
# Iteration 50 of 10000 completed!
# Iteration 60 of 10000 completed!
# Iteration 70 of 10000 completed!
# Iteration 80 of 10000 completed!
# Iteration 90 of 10000 completed!
# Iteration 100 of 10000 completed!
# Iteration 110 of 10000 completed!
# Iteration 120 of 10000 completed!
# Iteration 130 of 10000 completed!
# Iteration 140 of 10000 completed!
# Iteration 150 of 10000 completed!
# Iteration 160 of 10000 completed!
# Iteration 170 of 10000 completed!
# Iteration 180 of 10000 completed!
# Iteration 190 of 10000 completed!
# Iteration 200 of 10000 completed!
# Iteration 210 of 10000 completed!
# Iteration 220 of 10000 completed!
# Iteration 230 of 10000 completed!
# Iteration 240 of 10000 completed!
# Iteration 250 of 10000 completed!
# Iteration 260 of 10000 completed!
# Iteration 270 of 10000 completed!
# Iteration 280 of 10000 completed!
# Iteration 290 of 10000 completed!
# Iteration 300 of 10000 completed!
# Iteration 310 of 10000 completed!
# Iteration 320 of 10000 completed!
# Iteration 330 of 10000 completed!
# Iteration 340 of 10000 completed!
# Iteration 350 of 10000 completed!
# Iteration 360 of 10000 completed!
# Iteration 370 of 10000 completed!
# Iteration 380 of 10000 completed!
# Iteration 390 of 10000 completed!
# Iteration 400 of 10000 completed!
# Iteration 410 of 10000 completed!
# Iteration 420 of 10000 completed!
# Iteration 430 of 10000 completed!
# Iteration 440 of 10000 completed!
# Iteration 450 of 10000 completed!
# Iteration 460 of 10000 completed!
# Iteration 470 of 10000 completed!
# Iteration 480 of 10000 completed!
# Iteration 490 of 10000 completed!
# Iteration 500 of 10000 completed!
# Iteration 510 of 10000 completed!
# Iteration 520 of 10000 completed!
# Iteration 530 of 10000 completed!
# Iteration 540 of 10000 completed!
# Iteration 550 of 10000 completed!
# Iteration 560 of 10000 completed!
# Iteration 570 of 10000 completed!
# Iteration 580 of 10000 completed!
# Iteration 590 of 10000 completed!
# Iteration 600 of 10000 completed!
# Iteration 610 of 10000 completed!
# Iteration 620 of 10000 completed!
# Iteration 630 of 10000 completed!
# Iteration 640 of 10000 completed!
# Iteration 650 of 10000 completed!
# Iteration 660 of 10000 completed!
# Iteration 670 of 10000 completed!
# Iteration 680 of 10000 completed!
# Iteration 690 of 10000 completed!
# Iteration 700 of 10000 completed!
# Iteration 710 of 10000 completed!
# Iteration 720 of 10000 completed!
# Iteration 730 of 10000 completed!
# Iteration 740 of 10000 completed!
# Iteration 750 of 10000 completed!
# Iteration 760 of 10000 completed!
# Iteration 770 of 10000 completed!
# Iteration 780 of 10000 completed!
# Iteration 790 of 10000 completed!
# Iteration 800 of 10000 completed!
# Iteration 810 of 10000 completed!
# Iteration 820 of 10000 completed!
# Iteration 830 of 10000 completed!
# Iteration 840 of 10000 completed!
# Iteration 850 of 10000 completed!
# Iteration 860 of 10000 completed!
# Iteration 870 of 10000 completed!
# Iteration 880 of 10000 completed!
# Iteration 890 of 10000 completed!
# Iteration 900 of 10000 completed!
# Iteration 910 of 10000 completed!
# Iteration 920 of 10000 completed!
# Iteration 930 of 10000 completed!
# Iteration 940 of 10000 completed!
# Iteration 950 of 10000 completed!
# Iteration 960 of 10000 completed!
# Iteration 970 of 10000 completed!
# Iteration 980 of 10000 completed!
# Iteration 990 of 10000 completed!
# Iteration 1000 of 10000 completed!
# Iteration 1010 of 10000 completed!
# Iteration 1020 of 10000 completed!
# Iteration 1030 of 10000 completed!
# Iteration 1040 of 10000 completed!
# Iteration 1050 of 10000 completed!
# Iteration 1060 of 10000 completed!
# Iteration 1070 of 10000 completed!
# Iteration 1080 of 10000 completed!
# Iteration 1090 of 10000 completed!
# Iteration 1100 of 10000 completed!
# Iteration 1110 of 10000 completed!
# Iteration 1120 of 10000 completed!
# Iteration 1130 of 10000 completed!
# Iteration 1140 of 10000 completed!
# Iteration 1150 of 10000 completed!
# Iteration 1160 of 10000 completed!
# Iteration 1170 of 10000 completed!
# Iteration 1180 of 10000 completed!
# Iteration 1190 of 10000 completed!
# Iteration 1200 of 10000 completed!
# Iteration 1210 of 10000 completed!
# Iteration 1220 of 10000 completed!
# Iteration 1230 of 10000 completed!
# Iteration 1240 of 10000 completed!
# Iteration 1250 of 10000 completed!
# Iteration 1260 of 10000 completed!
# Iteration 1270 of 10000 completed!
# Iteration 1280 of 10000 completed!
# Iteration 1290 of 10000 completed!
# Iteration 1300 of 10000 completed!
# Iteration 1310 of 10000 completed!
# Iteration 1320 of 10000 completed!
# Iteration 1330 of 10000 completed!
# Iteration 1340 of 10000 completed!
# Iteration 1350 of 10000 completed!
# Iteration 1360 of 10000 completed!
# Iteration 1370 of 10000 completed!
# Iteration 1380 of 10000 completed!
# Iteration 1390 of 10000 completed!
# Iteration 1400 of 10000 completed!
# Iteration 1410 of 10000 completed!
# Iteration 1420 of 10000 completed!
# Iteration 1430 of 10000 completed!
# Iteration 1440 of 10000 completed!
# Iteration 1450 of 10000 completed!
# Iteration 1460 of 10000 completed!
# Iteration 1470 of 10000 completed!
# Iteration 1480 of 10000 completed!
# Iteration 1490 of 10000 completed!
# Iteration 1500 of 10000 completed!
# Iteration 1510 of 10000 completed!
# Iteration 1520 of 10000 completed!
# Iteration 1530 of 10000 completed!
# Iteration 1540 of 10000 completed!
# Iteration 1550 of 10000 completed!
# Iteration 1560 of 10000 completed!
# Iteration 1570 of 10000 completed!
# Iteration 1580 of 10000 completed!
# Iteration 1590 of 10000 completed!
# Iteration 1600 of 10000 completed!
# Iteration 1610 of 10000 completed!
# Iteration 1620 of 10000 completed!
# Iteration 1630 of 10000 completed!
# Iteration 1640 of 10000 completed!
# Iteration 1650 of 10000 completed!
# Iteration 1660 of 10000 completed!
# Iteration 1670 of 10000 completed!
# Iteration 1680 of 10000 completed!
# Iteration 1690 of 10000 completed!
# Iteration 1700 of 10000 completed!
# Iteration 1710 of 10000 completed!
# Iteration 1720 of 10000 completed!
# Iteration 1730 of 10000 completed!
# Iteration 1740 of 10000 completed!
# Iteration 1750 of 10000 completed!
# Iteration 1760 of 10000 completed!
# Iteration 1770 of 10000 completed!
# Iteration 1780 of 10000 completed!
# Iteration 1790 of 10000 completed!
# Iteration 1800 of 10000 completed!
# Iteration 1810 of 10000 completed!
# Iteration 1820 of 10000 completed!
# Iteration 1830 of 10000 completed!
# Iteration 1840 of 10000 completed!
# Iteration 1850 of 10000 completed!
# Iteration 1860 of 10000 completed!
# Iteration 1870 of 10000 completed!
# Iteration 1880 of 10000 completed!
# Iteration 1890 of 10000 completed!
# Iteration 1900 of 10000 completed!
# Iteration 1910 of 10000 completed!
# Iteration 1920 of 10000 completed!
# Iteration 1930 of 10000 completed!
# Iteration 1940 of 10000 completed!
# Iteration 1950 of 10000 completed!
# Iteration 1960 of 10000 completed!
# Iteration 1970 of 10000 completed!
# Iteration 1980 of 10000 completed!
# Iteration 1990 of 10000 completed!
# Iteration 2000 of 10000 completed!
# Iteration 2010 of 10000 completed!
# Iteration 2020 of 10000 completed!
# Iteration 2030 of 10000 completed!
# Iteration 2040 of 10000 completed!
# Iteration 2050 of 10000 completed!
# Iteration 2060 of 10000 completed!
# Iteration 2070 of 10000 completed!
# Iteration 2080 of 10000 completed!
# Iteration 2090 of 10000 completed!
# Iteration 2100 of 10000 completed!
# Iteration 2110 of 10000 completed!
# Iteration 2120 of 10000 completed!
# Iteration 2130 of 10000 completed!
# Iteration 2140 of 10000 completed!
# Iteration 2150 of 10000 completed!
# Iteration 2160 of 10000 completed!
# Iteration 2170 of 10000 completed!
# Iteration 2180 of 10000 completed!
# Iteration 2190 of 10000 completed!
# Iteration 2200 of 10000 completed!
# Iteration 2210 of 10000 completed!
# Iteration 2220 of 10000 completed!
# Iteration 2230 of 10000 completed!
# Iteration 2240 of 10000 completed!
# Iteration 2250 of 10000 completed!
# Iteration 2260 of 10000 completed!
# Iteration 2270 of 10000 completed!
# Iteration 2280 of 10000 completed!
# Iteration 2290 of 10000 completed!
# Iteration 2300 of 10000 completed!
# Iteration 2310 of 10000 completed!
# Iteration 2320 of 10000 completed!
# Iteration 2330 of 10000 completed!
# Iteration 2340 of 10000 completed!
# Iteration 2350 of 10000 completed!
# Iteration 2360 of 10000 completed!
# Iteration 2370 of 10000 completed!
# Iteration 2380 of 10000 completed!
# Iteration 2390 of 10000 completed!
# Iteration 2400 of 10000 completed!
# Iteration 2410 of 10000 completed!
# Iteration 2420 of 10000 completed!
# Iteration 2430 of 10000 completed!
# Iteration 2440 of 10000 completed!
# Iteration 2450 of 10000 completed!
# Iteration 2460 of 10000 completed!
# Iteration 2470 of 10000 completed!
# Iteration 2480 of 10000 completed!
# Iteration 2490 of 10000 completed!
# Iteration 2500 of 10000 completed!
# Iteration 2510 of 10000 completed!
# Iteration 2520 of 10000 completed!
# Iteration 2530 of 10000 completed!
# Iteration 2540 of 10000 completed!
# Iteration 2550 of 10000 completed!
# Iteration 2560 of 10000 completed!
# Iteration 2570 of 10000 completed!
# Iteration 2580 of 10000 completed!
# Iteration 2590 of 10000 completed!
# Iteration 2600 of 10000 completed!
# Iteration 2610 of 10000 completed!
# Iteration 2620 of 10000 completed!
# Iteration 2630 of 10000 completed!
# Iteration 2640 of 10000 completed!
# Iteration 2650 of 10000 completed!
# Iteration 2660 of 10000 completed!
# Iteration 2670 of 10000 completed!
# Iteration 2680 of 10000 completed!
# Iteration 2690 of 10000 completed!
# Iteration 2700 of 10000 completed!
# Iteration 2710 of 10000 completed!
# Iteration 2720 of 10000 completed!
# Iteration 2730 of 10000 completed!
# Iteration 2740 of 10000 completed!
# Iteration 2750 of 10000 completed!
# Iteration 2760 of 10000 completed!
# Iteration 2770 of 10000 completed!
# Iteration 2780 of 10000 completed!
# Iteration 2790 of 10000 completed!
# Iteration 2800 of 10000 completed!
# Iteration 2810 of 10000 completed!
# Iteration 2820 of 10000 completed!
# Iteration 2830 of 10000 completed!
# Iteration 2840 of 10000 completed!
# Iteration 2850 of 10000 completed!
# Iteration 2860 of 10000 completed!
# Iteration 2870 of 10000 completed!
# Iteration 2880 of 10000 completed!
# Iteration 2890 of 10000 completed!
# Iteration 2900 of 10000 completed!
# Iteration 2910 of 10000 completed!
# Iteration 2920 of 10000 completed!
# Iteration 2930 of 10000 completed!
# Iteration 2940 of 10000 completed!
# Iteration 2950 of 10000 completed!
# Iteration 2960 of 10000 completed!
# Iteration 2970 of 10000 completed!
# Iteration 2980 of 10000 completed!
# Iteration 2990 of 10000 completed!
# Iteration 3000 of 10000 completed!
# Iteration 3010 of 10000 completed!
# Iteration 3020 of 10000 completed!
# Iteration 3030 of 10000 completed!
# Iteration 3040 of 10000 completed!
# Iteration 3050 of 10000 completed!
# Iteration 3060 of 10000 completed!
# Iteration 3070 of 10000 completed!
# Iteration 3080 of 10000 completed!
# Iteration 3090 of 10000 completed!
# Iteration 3100 of 10000 completed!
# Iteration 3110 of 10000 completed!
# Iteration 3120 of 10000 completed!
# Iteration 3130 of 10000 completed!
# Iteration 3140 of 10000 completed!
# Iteration 3150 of 10000 completed!
# Iteration 3160 of 10000 completed!
# Iteration 3170 of 10000 completed!
# Iteration 3180 of 10000 completed!
# Iteration 3190 of 10000 completed!
# Iteration 3200 of 10000 completed!
# Iteration 3210 of 10000 completed!
# Iteration 3220 of 10000 completed!
# Iteration 3230 of 10000 completed!
# Iteration 3240 of 10000 completed!
# Iteration 3250 of 10000 completed!
# Iteration 3260 of 10000 completed!
# Iteration 3270 of 10000 completed!
# Iteration 3280 of 10000 completed!
# Iteration 3290 of 10000 completed!
# Iteration 3300 of 10000 completed!
# Iteration 3310 of 10000 completed!
# Iteration 3320 of 10000 completed!
# Iteration 3330 of 10000 completed!
# Iteration 3340 of 10000 completed!
# Iteration 3350 of 10000 completed!
# Iteration 3360 of 10000 completed!
# Iteration 3370 of 10000 completed!
# Iteration 3380 of 10000 completed!
# Iteration 3390 of 10000 completed!
# Iteration 3400 of 10000 completed!
# Iteration 3410 of 10000 completed!
# Iteration 3420 of 10000 completed!
# Iteration 3430 of 10000 completed!
# Iteration 3440 of 10000 completed!
# Iteration 3450 of 10000 completed!
# Iteration 3460 of 10000 completed!
# Iteration 3470 of 10000 completed!
# Iteration 3480 of 10000 completed!
# Iteration 3490 of 10000 completed!
# Iteration 3500 of 10000 completed!
# Iteration 3510 of 10000 completed!
# Iteration 3520 of 10000 completed!
# Iteration 3530 of 10000 completed!
# Iteration 3540 of 10000 completed!
# Iteration 3550 of 10000 completed!
# Iteration 3560 of 10000 completed!
# Iteration 3570 of 10000 completed!
# Iteration 3580 of 10000 completed!
# Iteration 3590 of 10000 completed!
# Iteration 3600 of 10000 completed!
# Iteration 3610 of 10000 completed!
# Iteration 3620 of 10000 completed!
# Iteration 3630 of 10000 completed!
# Iteration 3640 of 10000 completed!
# Iteration 3650 of 10000 completed!
# Iteration 3660 of 10000 completed!
# Iteration 3670 of 10000 completed!
# Iteration 3680 of 10000 completed!
# Iteration 3690 of 10000 completed!
# Iteration 3700 of 10000 completed!
# Iteration 3710 of 10000 completed!
# Iteration 3720 of 10000 completed!
# Iteration 3730 of 10000 completed!
# Iteration 3740 of 10000 completed!
# Iteration 3750 of 10000 completed!
# Iteration 3760 of 10000 completed!
# Iteration 3770 of 10000 completed!
# Iteration 3780 of 10000 completed!
# Iteration 3790 of 10000 completed!
# Iteration 3800 of 10000 completed!
# Iteration 3810 of 10000 completed!
# Iteration 3820 of 10000 completed!
# Iteration 3830 of 10000 completed!
# Iteration 3840 of 10000 completed!
# Iteration 3850 of 10000 completed!
# Iteration 3860 of 10000 completed!
# Iteration 3870 of 10000 completed!
# Iteration 3880 of 10000 completed!
# Iteration 3890 of 10000 completed!
# Iteration 3900 of 10000 completed!
# Iteration 3910 of 10000 completed!
# Iteration 3920 of 10000 completed!
# Iteration 3930 of 10000 completed!
# Iteration 3940 of 10000 completed!
# Iteration 3950 of 10000 completed!
# Iteration 3960 of 10000 completed!
# Iteration 3970 of 10000 completed!
# Iteration 3980 of 10000 completed!
# Iteration 3990 of 10000 completed!
# Iteration 4000 of 10000 completed!
# Iteration 4010 of 10000 completed!
# Iteration 4020 of 10000 completed!
# Iteration 4030 of 10000 completed!
# Iteration 4040 of 10000 completed!
# Iteration 4050 of 10000 completed!
# Iteration 4060 of 10000 completed!
# Iteration 4070 of 10000 completed!
# Iteration 4080 of 10000 completed!
# Iteration 4090 of 10000 completed!
# Iteration 4100 of 10000 completed!
# Iteration 4110 of 10000 completed!
# Iteration 4120 of 10000 completed!
# Iteration 4130 of 10000 completed!
# Iteration 4140 of 10000 completed!
# Iteration 4150 of 10000 completed!
# Iteration 4160 of 10000 completed!
# Iteration 4170 of 10000 completed!
# Iteration 4180 of 10000 completed!
# Iteration 4190 of 10000 completed!
# Iteration 4200 of 10000 completed!
# Iteration 4210 of 10000 completed!
# Iteration 4220 of 10000 completed!
# Iteration 4230 of 10000 completed!
# Iteration 4240 of 10000 completed!
# Iteration 4250 of 10000 completed!
# Iteration 4260 of 10000 completed!
# Iteration 4270 of 10000 completed!
# Iteration 4280 of 10000 completed!
# Iteration 4290 of 10000 completed!
# Iteration 4300 of 10000 completed!
# Iteration 4310 of 10000 completed!
# Iteration 4320 of 10000 completed!
# Iteration 4330 of 10000 completed!
# Iteration 4340 of 10000 completed!
# Iteration 4350 of 10000 completed!
# Iteration 4360 of 10000 completed!
# Iteration 4370 of 10000 completed!
# Iteration 4380 of 10000 completed!
# Iteration 4390 of 10000 completed!
# Iteration 4400 of 10000 completed!
# Iteration 4410 of 10000 completed!
# Iteration 4420 of 10000 completed!
# Iteration 4430 of 10000 completed!
# Iteration 4440 of 10000 completed!
# Iteration 4450 of 10000 completed!
# Iteration 4460 of 10000 completed!
# Iteration 4470 of 10000 completed!
# Iteration 4480 of 10000 completed!
# Iteration 4490 of 10000 completed!
# Iteration 4500 of 10000 completed!
# Iteration 4510 of 10000 completed!
# Iteration 4520 of 10000 completed!
# Iteration 4530 of 10000 completed!
# Iteration 4540 of 10000 completed!
# Iteration 4550 of 10000 completed!
# Iteration 4560 of 10000 completed!
# Iteration 4570 of 10000 completed!
# Iteration 4580 of 10000 completed!
# Iteration 4590 of 10000 completed!
# Iteration 4600 of 10000 completed!
# Iteration 4610 of 10000 completed!
# Iteration 4620 of 10000 completed!
# Iteration 4630 of 10000 completed!
# Iteration 4640 of 10000 completed!
# Iteration 4650 of 10000 completed!
# Iteration 4660 of 10000 completed!
# Iteration 4670 of 10000 completed!
# Iteration 4680 of 10000 completed!
# Iteration 4690 of 10000 completed!
# Iteration 4700 of 10000 completed!
# Iteration 4710 of 10000 completed!
# Iteration 4720 of 10000 completed!
# Iteration 4730 of 10000 completed!
# Iteration 4740 of 10000 completed!
# Iteration 4750 of 10000 completed!
# Iteration 4760 of 10000 completed!
# Iteration 4770 of 10000 completed!
# Iteration 4780 of 10000 completed!
# Iteration 4790 of 10000 completed!
# Iteration 4800 of 10000 completed!
# Iteration 4810 of 10000 completed!
# Iteration 4820 of 10000 completed!
# Iteration 4830 of 10000 completed!
# Iteration 4840 of 10000 completed!
# Iteration 4850 of 10000 completed!
# Iteration 4860 of 10000 completed!
# Iteration 4870 of 10000 completed!
# Iteration 4880 of 10000 completed!
# Iteration 4890 of 10000 completed!
# Iteration 4900 of 10000 completed!
# Iteration 4910 of 10000 completed!
# Iteration 4920 of 10000 completed!
# Iteration 4930 of 10000 completed!
# Iteration 4940 of 10000 completed!
# Iteration 4950 of 10000 completed!
# Iteration 4960 of 10000 completed!
# Iteration 4970 of 10000 completed!
# Iteration 4980 of 10000 completed!
# Iteration 4990 of 10000 completed!
# Iteration 5000 of 10000 completed!
# Iteration 5010 of 10000 completed!
# Iteration 5020 of 10000 completed!
# Iteration 5030 of 10000 completed!
# Iteration 5040 of 10000 completed!
# Iteration 5050 of 10000 completed!
# Iteration 5060 of 10000 completed!
# Iteration 5070 of 10000 completed!
# Iteration 5080 of 10000 completed!
# Iteration 5090 of 10000 completed!
# Iteration 5100 of 10000 completed!
# Iteration 5110 of 10000 completed!
# Iteration 5120 of 10000 completed!
# Iteration 5130 of 10000 completed!
# Iteration 5140 of 10000 completed!
# Iteration 5150 of 10000 completed!
# Iteration 5160 of 10000 completed!
# Iteration 5170 of 10000 completed!
# Iteration 5180 of 10000 completed!
# Iteration 5190 of 10000 completed!
# Iteration 5200 of 10000 completed!
# Iteration 5210 of 10000 completed!
# Iteration 5220 of 10000 completed!
# Iteration 5230 of 10000 completed!
# Iteration 5240 of 10000 completed!
# Iteration 5250 of 10000 completed!
# Iteration 5260 of 10000 completed!
# Iteration 5270 of 10000 completed!
# Iteration 5280 of 10000 completed!
# Iteration 5290 of 10000 completed!
# Iteration 5300 of 10000 completed!
# Iteration 5310 of 10000 completed!
# Iteration 5320 of 10000 completed!
# Iteration 5330 of 10000 completed!
# Iteration 5340 of 10000 completed!
# Iteration 5350 of 10000 completed!
# Iteration 5360 of 10000 completed!
# Iteration 5370 of 10000 completed!
# Iteration 5380 of 10000 completed!
# Iteration 5390 of 10000 completed!
# Iteration 5400 of 10000 completed!
# Iteration 5410 of 10000 completed!
# Iteration 5420 of 10000 completed!
# Iteration 5430 of 10000 completed!
# Iteration 5440 of 10000 completed!
# Iteration 5450 of 10000 completed!
# Iteration 5460 of 10000 completed!
# Iteration 5470 of 10000 completed!
# Iteration 5480 of 10000 completed!
# Iteration 5490 of 10000 completed!
# Iteration 5500 of 10000 completed!
# Iteration 5510 of 10000 completed!
# Iteration 5520 of 10000 completed!
# Iteration 5530 of 10000 completed!
# Iteration 5540 of 10000 completed!
# Iteration 5550 of 10000 completed!
# Iteration 5560 of 10000 completed!
# Iteration 5570 of 10000 completed!
# Iteration 5580 of 10000 completed!
# Iteration 5590 of 10000 completed!
# Iteration 5600 of 10000 completed!
# Iteration 5610 of 10000 completed!
# Iteration 5620 of 10000 completed!
# Iteration 5630 of 10000 completed!
# Iteration 5640 of 10000 completed!
# Iteration 5650 of 10000 completed!
# Iteration 5660 of 10000 completed!
# Iteration 5670 of 10000 completed!
# Iteration 5680 of 10000 completed!
# Iteration 5690 of 10000 completed!
# Iteration 5700 of 10000 completed!
# Iteration 5710 of 10000 completed!
# Iteration 5720 of 10000 completed!
# Iteration 5730 of 10000 completed!
# Iteration 5740 of 10000 completed!
# Iteration 5750 of 10000 completed!
# Iteration 5760 of 10000 completed!
# Iteration 5770 of 10000 completed!
# Iteration 5780 of 10000 completed!
# Iteration 5790 of 10000 completed!
# Iteration 5800 of 10000 completed!
# Iteration 5810 of 10000 completed!
# Iteration 5820 of 10000 completed!
# Iteration 5830 of 10000 completed!
# Iteration 5840 of 10000 completed!
# Iteration 5850 of 10000 completed!
# Iteration 5860 of 10000 completed!
# Iteration 5870 of 10000 completed!
# Iteration 5880 of 10000 completed!
# Iteration 5890 of 10000 completed!
# Iteration 5900 of 10000 completed!
# Iteration 5910 of 10000 completed!
# Iteration 5920 of 10000 completed!
# Iteration 5930 of 10000 completed!
# Iteration 5940 of 10000 completed!
# Iteration 5950 of 10000 completed!
# Iteration 5960 of 10000 completed!
# Iteration 5970 of 10000 completed!
# Iteration 5980 of 10000 completed!
# Iteration 5990 of 10000 completed!
# Iteration 6000 of 10000 completed!
# Iteration 6010 of 10000 completed!
# Iteration 6020 of 10000 completed!
# Iteration 6030 of 10000 completed!
# Iteration 6040 of 10000 completed!
# Iteration 6050 of 10000 completed!
# Iteration 6060 of 10000 completed!
# Iteration 6070 of 10000 completed!
# Iteration 6080 of 10000 completed!
# Iteration 6090 of 10000 completed!
# Iteration 6100 of 10000 completed!
# Iteration 6110 of 10000 completed!
# Iteration 6120 of 10000 completed!
# Iteration 6130 of 10000 completed!
# Iteration 6140 of 10000 completed!
# Iteration 6150 of 10000 completed!
# Iteration 6160 of 10000 completed!
# Iteration 6170 of 10000 completed!
# Iteration 6180 of 10000 completed!
# Iteration 6190 of 10000 completed!
# Iteration 6200 of 10000 completed!
# Iteration 6210 of 10000 completed!
# Iteration 6220 of 10000 completed!
# Iteration 6230 of 10000 completed!
# Iteration 6240 of 10000 completed!
# Iteration 6250 of 10000 completed!
# Iteration 6260 of 10000 completed!
# Iteration 6270 of 10000 completed!
# Iteration 6280 of 10000 completed!
# Iteration 6290 of 10000 completed!
# Iteration 6300 of 10000 completed!
# Iteration 6310 of 10000 completed!
# Iteration 6320 of 10000 completed!
# Iteration 6330 of 10000 completed!
# Iteration 6340 of 10000 completed!
# Iteration 6350 of 10000 completed!
# Iteration 6360 of 10000 completed!
# Iteration 6370 of 10000 completed!
# Iteration 6380 of 10000 completed!
# Iteration 6390 of 10000 completed!
# Iteration 6400 of 10000 completed!
# Iteration 6410 of 10000 completed!
# Iteration 6420 of 10000 completed!
# Iteration 6430 of 10000 completed!
# Iteration 6440 of 10000 completed!
# Iteration 6450 of 10000 completed!
# Iteration 6460 of 10000 completed!
# Iteration 6470 of 10000 completed!
# Iteration 6480 of 10000 completed!
# Iteration 6490 of 10000 completed!
# Iteration 6500 of 10000 completed!
# Iteration 6510 of 10000 completed!
# Iteration 6520 of 10000 completed!
# Iteration 6530 of 10000 completed!
# Iteration 6540 of 10000 completed!
# Iteration 6550 of 10000 completed!
# Iteration 6560 of 10000 completed!
# Iteration 6570 of 10000 completed!
# Iteration 6580 of 10000 completed!
# Iteration 6590 of 10000 completed!
# Iteration 6600 of 10000 completed!
# Iteration 6610 of 10000 completed!
# Iteration 6620 of 10000 completed!
# Iteration 6630 of 10000 completed!
# Iteration 6640 of 10000 completed!
# Iteration 6650 of 10000 completed!
# Iteration 6660 of 10000 completed!
# Iteration 6670 of 10000 completed!
# Iteration 6680 of 10000 completed!
# Iteration 6690 of 10000 completed!
# Iteration 6700 of 10000 completed!
# Iteration 6710 of 10000 completed!
# Iteration 6720 of 10000 completed!
# Iteration 6730 of 10000 completed!
# Iteration 6740 of 10000 completed!
# Iteration 6750 of 10000 completed!
# Iteration 6760 of 10000 completed!
# Iteration 6770 of 10000 completed!
# Iteration 6780 of 10000 completed!
# Iteration 6790 of 10000 completed!
# Iteration 6800 of 10000 completed!
# Iteration 6810 of 10000 completed!
# Iteration 6820 of 10000 completed!
# Iteration 6830 of 10000 completed!
# Iteration 6840 of 10000 completed!
# Iteration 6850 of 10000 completed!
# Iteration 6860 of 10000 completed!
# Iteration 6870 of 10000 completed!
# Iteration 6880 of 10000 completed!
# Iteration 6890 of 10000 completed!
# Iteration 6900 of 10000 completed!
# Iteration 6910 of 10000 completed!
# Iteration 6920 of 10000 completed!
# Iteration 6930 of 10000 completed!
# Iteration 6940 of 10000 completed!
# Iteration 6950 of 10000 completed!
# Iteration 6960 of 10000 completed!
# Iteration 6970 of 10000 completed!
# Iteration 6980 of 10000 completed!
# Iteration 6990 of 10000 completed!
# Iteration 7000 of 10000 completed!
# Iteration 7010 of 10000 completed!
# Iteration 7020 of 10000 completed!
# Iteration 7030 of 10000 completed!
# Iteration 7040 of 10000 completed!
# Iteration 7050 of 10000 completed!
# Iteration 7060 of 10000 completed!
# Iteration 7070 of 10000 completed!
# Iteration 7080 of 10000 completed!
# Iteration 7090 of 10000 completed!
# Iteration 7100 of 10000 completed!
# Iteration 7110 of 10000 completed!
# Iteration 7120 of 10000 completed!
# Iteration 7130 of 10000 completed!
# Iteration 7140 of 10000 completed!
# Iteration 7150 of 10000 completed!
# Iteration 7160 of 10000 completed!
# Iteration 7170 of 10000 completed!
# Iteration 7180 of 10000 completed!
# Iteration 7190 of 10000 completed!
# Iteration 7200 of 10000 completed!
# Iteration 7210 of 10000 completed!
# Iteration 7220 of 10000 completed!
# Iteration 7230 of 10000 completed!
# Iteration 7240 of 10000 completed!
# Iteration 7250 of 10000 completed!
# Iteration 7260 of 10000 completed!
# Iteration 7270 of 10000 completed!
# Iteration 7280 of 10000 completed!
# Iteration 7290 of 10000 completed!
# Iteration 7300 of 10000 completed!
# Iteration 7310 of 10000 completed!
# Iteration 7320 of 10000 completed!
# Iteration 7330 of 10000 completed!
# Iteration 7340 of 10000 completed!
# Iteration 7350 of 10000 completed!
# Iteration 7360 of 10000 completed!
# Iteration 7370 of 10000 completed!
# Iteration 7380 of 10000 completed!
# Iteration 7390 of 10000 completed!
# Iteration 7400 of 10000 completed!
# Iteration 7410 of 10000 completed!
# Iteration 7420 of 10000 completed!
# Iteration 7430 of 10000 completed!
# Iteration 7440 of 10000 completed!
# Iteration 7450 of 10000 completed!
# Iteration 7460 of 10000 completed!
# Iteration 7470 of 10000 completed!
# Iteration 7480 of 10000 completed!
# Iteration 7490 of 10000 completed!
# Iteration 7500 of 10000 completed!
# Iteration 7510 of 10000 completed!
# Iteration 7520 of 10000 completed!
# Iteration 7530 of 10000 completed!
# Iteration 7540 of 10000 completed!
# Iteration 7550 of 10000 completed!
# Iteration 7560 of 10000 completed!
# Iteration 7570 of 10000 completed!
# Iteration 7580 of 10000 completed!
# Iteration 7590 of 10000 completed!
# Iteration 7600 of 10000 completed!
# Iteration 7610 of 10000 completed!
# Iteration 7620 of 10000 completed!
# Iteration 7630 of 10000 completed!
# Iteration 7640 of 10000 completed!
# Iteration 7650 of 10000 completed!
# Iteration 7660 of 10000 completed!
# Iteration 7670 of 10000 completed!
# Iteration 7680 of 10000 completed!
# Iteration 7690 of 10000 completed!
# Iteration 7700 of 10000 completed!
# Iteration 7710 of 10000 completed!
# Iteration 7720 of 10000 completed!
# Iteration 7730 of 10000 completed!
# Iteration 7740 of 10000 completed!
# Iteration 7750 of 10000 completed!
# Iteration 7760 of 10000 completed!
# Iteration 7770 of 10000 completed!
# Iteration 7780 of 10000 completed!
# Iteration 7790 of 10000 completed!
# Iteration 7800 of 10000 completed!
# Iteration 7810 of 10000 completed!
# Iteration 7820 of 10000 completed!
# Iteration 7830 of 10000 completed!
# Iteration 7840 of 10000 completed!
# Iteration 7850 of 10000 completed!
# Iteration 7860 of 10000 completed!
# Iteration 7870 of 10000 completed!
# Iteration 7880 of 10000 completed!
# Iteration 7890 of 10000 completed!
# Iteration 7900 of 10000 completed!
# Iteration 7910 of 10000 completed!
# Iteration 7920 of 10000 completed!
# Iteration 7930 of 10000 completed!
# Iteration 7940 of 10000 completed!
# Iteration 7950 of 10000 completed!
# Iteration 7960 of 10000 completed!
# Iteration 7970 of 10000 completed!
# Iteration 7980 of 10000 completed!
# Iteration 7990 of 10000 completed!
# Iteration 8000 of 10000 completed!
# Iteration 8010 of 10000 completed!
# Iteration 8020 of 10000 completed!
# Iteration 8030 of 10000 completed!
# Iteration 8040 of 10000 completed!
# Iteration 8050 of 10000 completed!
# Iteration 8060 of 10000 completed!
# Iteration 8070 of 10000 completed!
# Iteration 8080 of 10000 completed!
# Iteration 8090 of 10000 completed!
# Iteration 8100 of 10000 completed!
# Iteration 8110 of 10000 completed!
# Iteration 8120 of 10000 completed!
# Iteration 8130 of 10000 completed!
# Iteration 8140 of 10000 completed!
# Iteration 8150 of 10000 completed!
# Iteration 8160 of 10000 completed!
# Iteration 8170 of 10000 completed!
# Iteration 8180 of 10000 completed!
# Iteration 8190 of 10000 completed!
# Iteration 8200 of 10000 completed!
# Iteration 8210 of 10000 completed!
# Iteration 8220 of 10000 completed!
# Iteration 8230 of 10000 completed!
# Iteration 8240 of 10000 completed!
# Iteration 8250 of 10000 completed!
# Iteration 8260 of 10000 completed!
# Iteration 8270 of 10000 completed!
# Iteration 8280 of 10000 completed!
# Iteration 8290 of 10000 completed!
# Iteration 8300 of 10000 completed!
# Iteration 8310 of 10000 completed!
# Iteration 8320 of 10000 completed!
# Iteration 8330 of 10000 completed!
# Iteration 8340 of 10000 completed!
# Iteration 8350 of 10000 completed!
# Iteration 8360 of 10000 completed!
# Iteration 8370 of 10000 completed!
# Iteration 8380 of 10000 completed!
# Iteration 8390 of 10000 completed!
# Iteration 8400 of 10000 completed!
# Iteration 8410 of 10000 completed!
# Iteration 8420 of 10000 completed!
# Iteration 8430 of 10000 completed!
# Iteration 8440 of 10000 completed!
# Iteration 8450 of 10000 completed!
# Iteration 8460 of 10000 completed!
# Iteration 8470 of 10000 completed!
# Iteration 8480 of 10000 completed!
# Iteration 8490 of 10000 completed!
# Iteration 8500 of 10000 completed!
# Iteration 8510 of 10000 completed!
# Iteration 8520 of 10000 completed!
# Iteration 8530 of 10000 completed!
# Iteration 8540 of 10000 completed!
# Iteration 8550 of 10000 completed!
# Iteration 8560 of 10000 completed!
# Iteration 8570 of 10000 completed!
# Iteration 8580 of 10000 completed!
# Iteration 8590 of 10000 completed!
# Iteration 8600 of 10000 completed!
# Iteration 8610 of 10000 completed!
# Iteration 8620 of 10000 completed!
# Iteration 8630 of 10000 completed!
# Iteration 8640 of 10000 completed!
# Iteration 8650 of 10000 completed!
# Iteration 8660 of 10000 completed!
# Iteration 8670 of 10000 completed!
# Iteration 8680 of 10000 completed!
# Iteration 8690 of 10000 completed!
# Iteration 8700 of 10000 completed!
# Iteration 8710 of 10000 completed!
# Iteration 8720 of 10000 completed!
# Iteration 8730 of 10000 completed!
# Iteration 8740 of 10000 completed!
# Iteration 8750 of 10000 completed!
# Iteration 8760 of 10000 completed!
# Iteration 8770 of 10000 completed!
# Iteration 8780 of 10000 completed!
# Iteration 8790 of 10000 completed!
# Iteration 8800 of 10000 completed!
# Iteration 8810 of 10000 completed!
# Iteration 8820 of 10000 completed!
# Iteration 8830 of 10000 completed!
# Iteration 8840 of 10000 completed!
# Iteration 8850 of 10000 completed!
# Iteration 8860 of 10000 completed!
# Iteration 8870 of 10000 completed!
# Iteration 8880 of 10000 completed!
# Iteration 8890 of 10000 completed!
# Iteration 8900 of 10000 completed!
# Iteration 8910 of 10000 completed!
# Iteration 8920 of 10000 completed!
# Iteration 8930 of 10000 completed!
# Iteration 8940 of 10000 completed!
# Iteration 8950 of 10000 completed!
# Iteration 8960 of 10000 completed!
# Iteration 8970 of 10000 completed!
# Iteration 8980 of 10000 completed!
# Iteration 8990 of 10000 completed!
# Iteration 9000 of 10000 completed!
# Iteration 9010 of 10000 completed!
# Iteration 9020 of 10000 completed!
# Iteration 9030 of 10000 completed!
# Iteration 9040 of 10000 completed!
# Iteration 9050 of 10000 completed!
# Iteration 9060 of 10000 completed!
# Iteration 9070 of 10000 completed!
# Iteration 9080 of 10000 completed!
# Iteration 9090 of 10000 completed!
# Iteration 9100 of 10000 completed!
# Iteration 9110 of 10000 completed!
# Iteration 9120 of 10000 completed!
# Iteration 9130 of 10000 completed!
# Iteration 9140 of 10000 completed!
# Iteration 9150 of 10000 completed!
# Iteration 9160 of 10000 completed!
# Iteration 9170 of 10000 completed!
# Iteration 9180 of 10000 completed!
# Iteration 9190 of 10000 completed!
# Iteration 9200 of 10000 completed!
# Iteration 9210 of 10000 completed!
# Iteration 9220 of 10000 completed!
# Iteration 9230 of 10000 completed!
# Iteration 9240 of 10000 completed!
# Iteration 9250 of 10000 completed!
# Iteration 9260 of 10000 completed!
# Iteration 9270 of 10000 completed!
# Iteration 9280 of 10000 completed!
# Iteration 9290 of 10000 completed!
# Iteration 9300 of 10000 completed!
# Iteration 9310 of 10000 completed!
# Iteration 9320 of 10000 completed!
# Iteration 9330 of 10000 completed!
# Iteration 9340 of 10000 completed!
# Iteration 9350 of 10000 completed!
# Iteration 9360 of 10000 completed!
# Iteration 9370 of 10000 completed!
# Iteration 9380 of 10000 completed!
# Iteration 9390 of 10000 completed!
# Iteration 9400 of 10000 completed!
# Iteration 9410 of 10000 completed!
# Iteration 9420 of 10000 completed!
# Iteration 9430 of 10000 completed!
# Iteration 9440 of 10000 completed!
# Iteration 9450 of 10000 completed!
# Iteration 9460 of 10000 completed!
# Iteration 9470 of 10000 completed!
# Iteration 9480 of 10000 completed!
# Iteration 9490 of 10000 completed!
# Iteration 9500 of 10000 completed!
# Iteration 9510 of 10000 completed!
# Iteration 9520 of 10000 completed!
# Iteration 9530 of 10000 completed!
# Iteration 9540 of 10000 completed!
# Iteration 9550 of 10000 completed!
# Iteration 9560 of 10000 completed!
# Iteration 9570 of 10000 completed!
# Iteration 9580 of 10000 completed!
# Iteration 9590 of 10000 completed!
# Iteration 9600 of 10000 completed!
# Iteration 9610 of 10000 completed!
# Iteration 9620 of 10000 completed!
# Iteration 9630 of 10000 completed!
# Iteration 9640 of 10000 completed!
# Iteration 9650 of 10000 completed!
# Iteration 9660 of 10000 completed!
# Iteration 9670 of 10000 completed!
# Iteration 9680 of 10000 completed!
# Iteration 9690 of 10000 completed!
# Iteration 9700 of 10000 completed!
# Iteration 9710 of 10000 completed!
# Iteration 9720 of 10000 completed!
# Iteration 9730 of 10000 completed!
# Iteration 9740 of 10000 completed!
# Iteration 9750 of 10000 completed!
# Iteration 9760 of 10000 completed!
# Iteration 9770 of 10000 completed!
# Iteration 9780 of 10000 completed!
# Iteration 9790 of 10000 completed!
# Iteration 9800 of 10000 completed!
# Iteration 9810 of 10000 completed!
# Iteration 9820 of 10000 completed!
# Iteration 9830 of 10000 completed!
# Iteration 9840 of 10000 completed!
# Iteration 9850 of 10000 completed!
# Iteration 9860 of 10000 completed!
# Iteration 9870 of 10000 completed!
# Iteration 9880 of 10000 completed!
# Iteration 9890 of 10000 completed!
# Iteration 9900 of 10000 completed!
# Iteration 9910 of 10000 completed!
# Iteration 9920 of 10000 completed!
# Iteration 9930 of 10000 completed!
# Iteration 9940 of 10000 completed!
# Iteration 9950 of 10000 completed!
# Iteration 9960 of 10000 completed!
# Iteration 9970 of 10000 completed!
# Iteration 9980 of 10000 completed!
# Iteration 9990 of 10000 completed!
# Simulation completed!
# [291, 469, 218, 328, 222, 312, 247, 347, 295, 298, 427, 291, 347, 315, 208, 295, 384, 303, 251, 302, 266, 348, 295, 317, 296, 285, 364, 318, 240, 292, 361, 315, 261, 313, 267, 338, 290, 303, 323, 185, 294, 351, 322, 247, 314, 235, 328, 279, 307, 309, 221, 297, 346, 297, 332, 270, 276, 360, 289, 325, 306, 245, 292, 351, 287, 340, 288, 308, 291, 316, 295, 284, 386, 308, 293, 298, 362, 298, 352, 304, 276, 309, 279, 312, 302, 273, 304, 289, 321, 283, 326, 268, 323, 287, 296, 344, 309, 272, 291, 328, 306, 281, 307, 284, 303, 310, 236, 297, 319, 301, 265, 314, 273, 321, 288, 301, 307, 215, 284, 319, 292, 323, 288, 280, 324, 285, 334, 284, 281, 327, 305, 271, 313, 288, 283, 349, 294, 325, 281, 321, 282, 308, 306, 257, 307, 292, 304, 306, 257, 296, 313, 298, 317, 298, 304, 286, 296, 328, 292, 299, 332, 316, 285, 303, 288, 315, 283, 308, 302, 273, 312, 307, 272, 286, 324, 302, 280, 302, 271, 310, 298, 307, 304, 236, 278, 311, 308, 245, 308, 253, 299, 308, 290, 328, 292, 287, 319, 309, 267, 299, 298, 357, 294, 322, 290, 314, 285, 312, 296, 312, 292, 286, 359, 304, 287, 300, 326, 287, 318, 272, 330, 290, 313, 300, 299, 350, 315, 282, 315, 283, 318, 298, 306, 307, 272, 320, 284, 307, 335, 262, 301, 304, 248, 308, 285, 297, 334, 323, 271, 307, 273, 306, 291, 316, 275, 312, 295, 306, 308, 224, 300, 299, 318, 306, 273, 309, 287, 300, 317, 281, 310, 292, 301, 286, 328, 276, 309, 300, 283, 332, 297, 302, 298, 305, 294, 299, 349, 324, 290, 316, 309, 279, 303, 297, 284, 332, 298, 312, 309, 289, 298, 334, 306, 282, 300, 311, 287, 308, 298, 303, 295, 313, 299, 302, 297, 304, 310, 278, 300, 317, 284, 300, 326, 285, 311, 290, 322, 299, 308, 302, 284, 308, 301, 277, 301, 309, 267, 301, 286, 300, 312, 295, 312, 285, 310, 284, 312, 286, 298, 333, 320, 278, 299, 333, 303, 269, 297, 333, 291, 307, 305, 297, 301, 273, 310, 305, 273, 297, 320, 304, 276, 309, 295, 312, 272, 317, 297, 307, 284, 310, 293, 304, 318, 214, 291, 320, 304, 256, 298, 325, 292, 312, 276, 323, 288, 292, 334, 298, 317, 297, 305, 305, 255, 300, 309, 279, 315, 284, 301, 302, 271, 295, 309, 302, 281, 308, 288, 306, 296, 302, 302, 254, 292, 310, 298, 309, 302, 260, 302, 284, 306, 285, 296, 308, 303, 273, 302, 293, 292, 312, 305, 278, 302, 302, 212, 295, 296, 332, 295, 299, 313, 303, 278, 302, 287, 302, 292, 304, 308, 262, 300, 290, 324, 291, 311, 289, 289, 341, 277, 305, 282, 315, 279, 325, 301, 262, 300, 322, 285, 316, 282, 307, 295, 295, 326, 318, 277, 302, 286, 298, 361, 301, 274, 298, 333, 299, 336, 294, 322, 296, 316, 291, 305, 303, 266, 327, 281, 317, 298, 304, 299, 310, 281, 321, 298, 293, 340, 311, 285, 309, 285, 305, 309, 263, 305, 286, 303, 308, 285, 299, 313, 296, 306, 283, 318, 285, 303, 314, 262, 304, 292, 298, 319, 303, 277, 310, 287, 311, 287, 312, 300, 279, 314, 294, 296, 319, 302, 283, 304, 296, 302, 299, 299, 330, 301, 290, 295, 331, 297, 314, 315, 295, 296, 300, 325, 306, 281, 298, 325, 292, 320, 312, 292, 306, 296, 305, 292, 313, 298, 297, 330, 309, 303, 277, 303, 293, 292, 321, 303, 282, 321, 308, 271, 306, 268, 317, 294, 296, 330, 312, 277, 310, 307, 238, 308, 274, 304, 285, 299, 329, 295, 311, 299, 292, 328, 306, 269, 300, 310, 283, 323, 281, 311, 287, 312, 297, 308, 297, 301, 307, 260, 308, 308, 250, 289, 306, 300, 303, 258, 313, 296, 292, 320, 301, 278, 304, 291, 317, 286, 293, 328, 284, 315, 303, 275, 299, 320, 301, 270, 314, 286, 308, 301, 260, 299, 310, 301, 267, 300, 311, 291, 303, 287, 304, 287, 296, 321, 290, 318, 285, 300, 319, 298, 304, 294, 301, 290, 313, 277, 332, 288, 316, 296, 305, 302, 269, 305, 301, 274, 293, 308, 295, 314, 296, 306, 295, 299, 316, 299, 304, 304, 274, 306, 298, 294, 321, 300, 281, 324, 304, 275, 298, 323, 289, 318, 298, 308, 304, 289, 292, 317, 308, 276, 308, 294, 301, 305, 290, 294, 312, 307, 279, 313, 291, 305, 301, 280, 299, 304, 305, 282, 312, 291, 305, 290, 317, 287, 298, 318, 305, 275, 308, 300, 285, 305, 291, 308, 290, 300, 318, 287, 305, 294, 304, 298, 298, 322, 314, 288, 308, 302, 281, 297, 316, 295, 307, 302, 286, 312, 285, ...

# %%
sample_list = [0, 3, 1, 2]
which_index = 2
sample_list[which_index]
# Out:
# 1
